# %%
import pandas as pd

# %%
df = pd.read_csv('credit card taiwan svm algorithm.csv')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
missing = df.AGE.mean()

# %%
missing
# Out:
# 35.48549903326889

# %%
df.AGE = df.AGE.fillna(missing)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
data_file = pd.read_csv('1.04. Real-life example.csv')

# %%
data_file
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
import pandas as pd
df_encoded = pd.get_dummies(data_file, columns=['Brand'])

# %%
df_encoded
# Out:
#          Price       Body  Mileage  EngineV Engine Type Registration  Year  \
# 0       4200.0      sedan      277      2.0      Petrol          yes  1991
# 1       7900.0        van      427      2.9      Diesel          yes  1999
# 2      13300.0      sedan      358      5.0         Gas          yes  2003
# 3      23000.0  crossover      240      4.2      Petrol          yes  2007
# 4      18300.0  crossover      120      2.0      Petrol          yes  2011
# ...        ...        ...      ...      ...         ...          ...   ...
# 4340  125000.0      sedan        9      3.0      Diesel          yes  2014
# 4341    6500.0      sedan        1      3.5      Petrol          yes  1999
# 4342    8000.0      sedan      194      2.0      Petrol          yes  1985
# 4343   14200.0      sedan       31      NaN      Petrol          yes  2014
# 4344   13500.0        van      124      2.0      Diesel          yes  2013
#
# ...
